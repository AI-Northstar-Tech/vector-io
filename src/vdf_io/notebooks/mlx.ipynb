# %%
# %pip install -U mlx
# Out:
# ...
#   Obtaining dependency information for mlx from https://files.pythonhosted.org/packages/cd/aa/75cfd183bfa9d291aa4d3f1b8c20ec1179c7483f2e96ede6fef66543ba7f/mlx-0.13.0-cp310-cp310-macosx_14_0_arm64.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 1.6 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: mlx
#     Found existing installation: mlx 0.12.2
#     Uninstalling mlx-0.12.2:
#       Successfully uninstalled mlx-0.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlx-lm 0.0.13 requires transformers>=4.38.0, but you have transformers 4.36.2 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show mlx-embedding-models
# Out:
# Name: mlx_embedding_models
# Version: 0.0.9
# Summary: Python utility for text embeddings in MLX.
# Home-page:
# Author:
# Author-email: Benjamin Anderson <ben@trytaylor.ai>
# License:
# Location: /Users/dhruvanand/miniforge3/lib/python3.10/site-packages
# Requires: awkward, mlx, numpy, scipy, torch, tqdm, transformers
# Required-by: vdf_io
# Note: you may need to restart the kernel to use updated packages.

# %%
from sentence_transformers import SentenceTransformer

model2 = SentenceTransformer("TaylorAI/bge-micro-v2")


from mlx_embedding_models.embedding import EmbeddingModel

model = EmbeddingModel.from_registry("bge-micro")
texts = [
    "isn't it nice to be inside such a fancy computer",
    "the horse raced past the barn fell",
]
embs = model.encode(texts)
print(embs.shape)
embs2 = model2.encode(texts)
# check if the embeddings are the same
import numpy as np

print(np.allclose(embs, embs2, atol=1e-5))
# Out:
# /Users/dhruvanand/miniforge3/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 100%|██████████| 2/2 [00:00<00:00, 17.48it/s, seq_len=16]
# (2, 384)
# False

# %%
# allclose per vector
[np.allclose(e1, e2, atol=1e-5) for e1, e2 in zip(embs, embs2)]
# Out:
# [False, False]

# %%
# dot product of each pair of embeddings
[np.dot(e1, e2) for e1, e2 in zip(embs, embs2)]
# Out:
# [5.987567, 6.2495027]

# %%
# %pip show mlx
# Out:
# /Users/dhruvanand/miniforge3/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Name: mlx
# Version: 0.13.0
# Summary: A framework for machine learning on Apple silicon.
# Home-page: https://github.com/ml-explore/mlx
# Author: MLX Contributors
# Author-email: mlx@group.apple.com
# License:
# Location: /Users/dhruvanand/miniforge3/lib/python3.10/site-packages
# Requires:
# Required-by: mlx-lm, mlx_embedding_models
# Note: you may need to restart the kernel to use updated packages.

# %%
# display the embeddings side by side using zip
from rich import print as rprint

rprint(list(zip(embs[0], embs2[0])))
# Out:
# [
#     (-0.00037605935, -0.002251906),
#     (-0.019109117, -0.1144171),
#     (0.044015713, 0.26354688),
#     (-0.04620378, -0.2766484),
#     (0.010541938, 0.06312104),
#     (-0.079727225, -0.4773724),
#     (0.028281407, 0.16933712),
#     (-0.009040847, -0.054132853),
#     (0.063943036, 0.3828632),
#     (-0.020726379, -0.12410035),
#     (-0.009690223, -0.05802066),
#     (0.040648088, 0.2433832),
#     (0.08746149, 0.5236812),
#     (-0.023482332, -0.14060216),
#     (-0.008800617, -0.052694056),
#     (0.02241449, 0.13420834),
#     (0.016776547, 0.10045072),
#     (-0.09233389, -0.55285555),
#     (-0.021378728, -0.12800619),
#     (0.07247151, 0.43392795),
#     (-0.0052091815, -0.031190868),
#     (-0.023425516, -0.1402619),
#     (-0.02594034, -0.15531942),
#     (-0.09212457, -0.55160207),
#     (-0.015449154, -0.092503),
#     (-0.017879454, -0.10705448),
#     (0.012323453, 0.07378781),
#     (-0.011874108, -0.07109719),
#     (-0.047724355, -0.28575283),
# ...
